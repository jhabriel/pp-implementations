# %% [markdown]
# # Rcihards' Equation: Convergence Test

# %% [markdown]
# * Author: Jhabriel Varela
# * E-mail: jhabriel.varela@uib.no
# * Date: 05.04.2019
# * Institution: PMG - UiB - Norway

# %% [markdown]
# ## Description of the problem

# %% [markdown]
# In this noteboook, we present a convergence test of the implementation of Richards' equation in PorePy. The equation is discretized using MPFA [[1](#ref)] in space, and backward Euler in time. We use the Automatic Differentiation framework from PorePy and solve the non-linear system using a modified Picard Iteration [[2](#ref)].
#
# The set of equations to be solved are
# $$
#     \frac{\partial \theta}{\partial t} + \nabla \cdot \mathbf{q} = f, \\
#     \mathbf{q} = - K k_r^w \nabla \psi,
# $$
#
# where $\theta$ is the water content, $\mathbf{q}$ is the Darcy's velocity, $f$ is a source term, $K$ is the permeability tensor, $k_r^w$ is the relative permeability and $\psi$ is the pressure head.
#
# Usually, $\theta$ and $k_r^w$ are non-linear functions of the pressure head. In this example we use the following relationships as in [[3](#ref)]:
# $$
# \theta(\psi) = \frac{1}{1-\psi}, \\
# k_r^w(\psi) = \psi^2.
# $$
#
# We assume that an exact time-dependent pressure head distribution is known such that [[3](#ref)]:
#
# $$
# \psi(x,y,t) = -tx(1-x)y(1-y) - 1.
# $$
#
# Assuming dirichlet boundary conditions, the boundary and initial conditions for an unit square are:
#
# $$
# \psi(0,y,t) = \psi(1,y,t) = \psi(x,0,t) = \psi(x,1,t) = \psi(x,y,0) = -1.
# $$
#
# With the prescribed solution and assuming $K$ = 1, we can derive the expressions for the Darcy's velocity and the source term:
#
# $$
# \mathbf{q}(x,y,t) = (txy(x - 1)(y - 1) + 1)^2 \begin{pmatrix} txy(y - 1) + ty(x - 1)(y - 1) \\
#                                                               txy(x - 1) + tx(x - 1)(y - 1)                                                                     \end{pmatrix},
# $$
#
# $$
# \begin{align}
# f(x,y,t) = & 2(txy(x - 1)(y - 1) + 1)(txy(x - 1) + tx(x - 1)(y - 1))^2 + \\
#            & 2(txy(x - 1)(y - 1) + 1)(txy(y - 1) + ty(x - 1)(y - 1))^2 + \\
#            & 2tx(txy(x - 1)(y - 1) + 1)^2(x - 1) + \\
#            & 2ty(txy(x - 1)(y - 1) + 1)^2(y - 1) - \\
#            &\frac{xy(x - 1)(y - 1)}{(txy(x - 1)(y - 1) + 2)^2}.
# \end{align}
# $$

# %% [markdown]
# ## The convergence analysis

# %% [markdown]
# Let $\psi$, $\tilde{\psi}$ and $\mathbf{q}$,$\mathbf{\tilde{q}}$ be the analytical and numerical pressure heads and Darcy's velocities, respectively. We define the global error $E$ as [[3](#ref)]
#
# $$
# E = \left(||\psi - \tilde{\psi}||_{L^2}^{2} + \tau ||\mathbf{q} \cdot \mathbf{n} - \mathbf{\tilde{q}} \cdot \mathbf{n} ||_{L^2}^2 \right)^{1/2},
# $$
#
# where $\tau$ is the time step and $\mathbf{n}$ is the normal vector pointing outwards.
#
# According to theoretical results [[2](#ref)], we should expect an error reduction of approximately a factor of $2$ by halving both, the spatial step $h$ and the time step size $\tau$.

# %% [markdown]
# ## Importing modules

# %%
import numpy as np
import scipy.sparse as sps
import porepy as pp
import matplotlib.pyplot as plt

from porepy.ad.forward_mode import Ad_array
np.set_printoptions(precision=5, suppress = True)

# %% [markdown]
# ## The convergence function

# %%
def convergence_richards(cell_num,time_levels):
    
    ## Computing relative permeabilities
    def arithmetic_mpfa_hyd(krw,g,bc,bc_val,psi_m0):
    
        """
        Computes the arithmetic average of the relative permability
        
        SYNOPSIS:
            arithmetic_mpfa_hyd(krw,g,bc_val,psi_m0)
        
        INPUT ARGUMENTS:
            krw         - Lambda function, relative permeability function krw = f(psi)
            g           - PorePy grid object
            bc_val      - NumPy array, containing values of boundary conditions
            psi_m0      - NumPy array, containing values of pressure head at the cell centers
        
        RETURNS:
            krw_ar      - Numpy array, contatining arithmetic averaged relative permeabilities 
                      at the face centers
        """
    
        neu_fcs = bc.is_neu.nonzero()    # neumann boundary faces
        dir_fcs = bc.is_dir.nonzero()    # dirichlet boundary faces
        int_fcs = g.get_internal_faces() # internal faces

        fcs_neigh = np.zeros((g.num_faces,2),dtype=int) #          
        fcs_neigh[:,0] = g.cell_face_as_dense()[0]      # faces neighbouring mapping
        fcs_neigh[:,1] = g.cell_face_as_dense()[1]      # 

        int_fcs_neigh = fcs_neigh[int_fcs]              # internal faces neighbouring mapping

        # Initializing 
        krw_ar = np.zeros(g.num_faces)

        # Neumann boundaries relative permeabilities
        krw_ar[neu_fcs] = 1.

        # Dirichlet boundaries relative permeabilities
        dir_cells_neigh = fcs_neigh[dir_fcs] # neighboring cells of dirichlet faces
        dir_cells = dir_cells_neigh[(dir_cells_neigh >= 0).nonzero()][0] # cells that share a dirichlet face
        krw_ar[dir_fcs] = 0.5 * (krw(bc_val[dir_fcs]) + krw(psi_m0[dir_cells]))

        # Internal faces relative permeabilities
        krw_ar[int_fcs] = 0.5 * (krw(psi_m0[int_fcs_neigh[:,0]]) + krw(psi_m0[int_fcs_neigh[:,1]]))

        return krw_ar

    ## Source term
    def source_term(g,t):
        
        x = g.cell_centers[0]
        y = g.cell_centers[1]
        
        f = 2*(t*x*y*(x - 1)*(y - 1) + 1)*(t*x*y*(x - 1) + t*x*(x - 1)*(y - 1))**2 + 2*(t*x*y*(x - 1)*(y - 1) + 1)*(t*x*y*(y - 1) + t*y*(x - 1)*(y - 1))**2 + 2*t*x*(t*x*y*(x - 1)*(y - 1) + 1)**2*(x - 1) + 2*t*y*(t*x*y*(x - 1)*(y - 1) + 1)**2*(y - 1) - (x*y*(x - 1)*(y - 1))/(t*x*y*(x - 1)*(y - 1) + 2)**2     
      
        return f

    ## Analytical solution
    def analytical(g,t):
        
        x_cntr = g.cell_centers[0]
        y_cntr = g.cell_centers[1]
        x_face = g.face_centers[0]
        y_face = g.face_centers[1]
        
        psi = -t*x_cntr*(1-x_cntr)*y_cntr*(1-y_cntr)-1
        
        q_x = (t*x_face*y_face*(x_face - 1)*(y_face - 1) + 1)**2*(t*x_face*y_face*(y_face - 1) + t*y_face*(x_face - 1)*(y_face - 1))
        q_y = (t*x_face*y_face*(x_face - 1)*(y_face - 1) + 1)**2*(t*x_face*y_face*(x_face - 1) + t*x_face*(x_face - 1)*(y_face - 1))
        Q = q_x * g.face_normals[0] + q_y * g.face_normals[1]
        
        return psi,Q
    
    ## Setting up the grid
    Nx = Ny = cell_num
    Lx = 1; Ly = 1
    g = pp.CartGrid([Nx,Ny], [Lx,Ly])
    g.compute_geometry()
    V = g.cell_volumes
    
    ## Creating the permeability second order tensor          
    perm = pp.SecondOrderTensor(g.dim, np.ones(g.num_cells))
    
    ## Boundary and initial conditions
    b_faces = g.tags['domain_boundary_faces'].nonzero()[0]

    # Extracting indices of boundary faces w.r.t g
    x_min = b_faces[g.face_centers[0,b_faces] < 0.0001]
    x_max = b_faces[g.face_centers[0,b_faces] > 0.9999*Lx]
    y_min = b_faces[g.face_centers[1,b_faces] < 0.0001]
    y_max = b_faces[g.face_centers[1,b_faces] > 0.9999*Ly]
    
    # Extracting indices of boundary faces w.r.t b_faces
    west   = np.in1d(b_faces,x_min).nonzero()
    east   = np.in1d(b_faces,x_max).nonzero()
    south  = np.in1d(b_faces,y_min).nonzero()
    north  = np.in1d(b_faces,y_max).nonzero()
    
    # Setting the tags at each boundary side
    labels = np.array([None]*b_faces.size)
    labels[east]   = 'dir'
    labels[west]   = 'dir'
    labels[south]  = 'dir'
    labels[north]  = 'dir'
    
    # Constructing the bc object
    bc = pp.BoundaryCondition(g, b_faces, labels)
    
    # Constructing the boundary values array
    bc_val = -1 * np.ones(g.num_faces)
    
    ## Creating the data object
    specified_parameters = {"second_order_tensor": perm, 
                        "bc": bc, 
                        "bc_values": bc_val}

    data = pp.initialize_default_data(g,{},"flow", specified_parameters)
    
    ## Performing the discretization using MPFA  
    # Instatiating the pp.Mpfa class
    solver = pp.Mpfa("flow")

    # MPFA discretization
    mpfa_F, mpfa_boundF, _, _ = solver.mpfa(g, perm, bc)
    mpfa_div = pp.fvutils.scalar_divergence(g)
    
    ## Creating MPFA discrete operators
    F      = lambda x: mpfa_F * x
    boundF = lambda x: mpfa_boundF * x
    div    = lambda x: mpfa_div * x
    
    # Water content
    theta = lambda psi: 1/(1-psi)

    # Specific moisture capacity
    C = lambda psi: 1/((1-psi)**2)

    # Relative permeability
    krw = lambda psi: psi**2
    
    # Arithmetic mean of relative permeability
    krw_ar = lambda psi_m: arithmetic_mpfa_hyd(krw,g,bc,bc_val,psi_m)

    # Multiphase Darcy Flux
    q = lambda psi,psi_m: (F(psi) + boundF(bc_val)) * krw_ar(psi_m)

    # Mass Conservation
    psi_eq = lambda psi,psi_n,psi_m,dt: div(q(psi,psi_m)) +  ((psi-psi_m)*C(psi_m) + 
                                                            theta(psi_m) - 
                                                            theta(psi_n)) * (V/dt) - \
                                                            source_term(g,times[tt]) * V
    
    ## Creating AD-object
    psi_ad = Ad_array(-1*np.ones(g.num_cells), sps.diags(np.ones(g.num_cells)))
    
    ## Time parameters
    t0 = 0                                # [s] Initial time
    tf = 1                                # [s] Final simulation time
    tLevels = time_levels                 # [-] Time levels
    times = np.linspace(t0,tf,tLevels+1)  # [s] Vector of time evaluations
    dt = np.diff(times)                   # [s] Vector of time steps

    ## Newton parameters
    newton_param = dict()
    newton_param['max_tol'] = 1E-8            # [cm] maximum absolute tolerance (pressure head)
    newton_param['max_iter'] = 10             # [iter] maximum number of iterations
    newton_param['abs_tol'] = 100             # [cm] absolute tolerance
    newton_param['iter'] = 1                  # [iter] iteration
    
    ## The time loop
    print("\n Performing simulation with h = {} and dt = {}. \n".format(1/Nx,dt[0]))
    
    tt = 0
    while times[tt] < tf:
           
        psi_n = psi_ad.val.copy()                                 # current time level
        newton_param.update({'abs_tol':100, 'iter':1})            # updating tolerance and iterations
        tt += 1
        
        # Newton loop
        while newton_param['abs_tol'] > newton_param['max_tol']   and \
              newton_param['iter']    < newton_param['max_iter']:      
              
            psi_m = psi_ad.val.copy()                                     # current iteration level
            eq = psi_eq(psi_ad,psi_n,psi_m,dt[tt-1])                      # calling discrete equation
            R = eq.val                                                    # determining residual
            J = eq.jac                                                    # determining Jacobian
            y = sps.linalg.spsolve(J,-R)                                  # Newton update
            psi_ad.val +=  y                                              # root for the k-th step
            newton_param['abs_tol'] = np.max(np.abs(psi_ad.val - psi_m))  # checking convergence        

            if newton_param['abs_tol'] <= newton_param['max_tol'] and newton_param['iter'] <= newton_param['max_iter']:
                print('Time: {0:4.4f} [s] \t Iter: {1:1d} \t Error: {2:4e} [cm]'.format(times[tt],newton_param['iter'],newton_param['abs_tol']))
            elif newton_param['iter'] > newton_param['max_iter']:
                 print('Error: Newton method did not converge!')
            else:
                 newton_param['iter'] += 1
                    
    ## Computing norm
    
    # Numerical results
    psi_num = psi_ad.val
    Q_num = q(psi_ad.val,psi_m)
    
    # Analytical results
    psi_ex,Q_ex = analytical(g,times[-1])
    
    # Global error
    E = (np.linalg.norm(psi_ex - psi_num)**2 + \
        dt[0] * np.linalg.norm(Q_ex - Q_num)**2)**(0.5)
    
    return E

# %% [markdown]
# ## Performing the analysis

# %%
# Number of cells and time levels
n_cells = np.array([10,20,40,80,160])
t_levels = np.array([10,20,40,80,160])
h = 1/n_cells
tau = 1/t_levels

# Intializing
E = np.zeros(len(n_cells))
E_reduction = np.zeros(len(n_cells)-1)

# Computing the errors
for i in range(len(E)):
    E[i] = convergence_richards(n_cells[i],t_levels[i])

# Computing the error reduction
for i in range(len(E_reduction)):
    E_reduction[i] = E[i]/E[i+1]
# Out:
#  Performing simulation with h = 0.1 and dt = 0.1.
#
# Time: 0.1000 [s] 	 Iter: 4 	 Error: 2.940312e-10 [cm]
# Time: 0.2000 [s] 	 Iter: 4 	 Error: 2.464822e-09 [cm]
# Time: 0.3000 [s] 	 Iter: 4 	 Error: 8.417291e-09 [cm]
# Time: 0.4000 [s] 	 Iter: 5 	 Error: 1.672171e-10 [cm]
# Time: 0.5000 [s] 	 Iter: 5 	 Error: 4.081639e-10 [cm]
# Time: 0.6000 [s] 	 Iter: 5 	 Error: 8.445145e-10 [cm]
# Time: 0.7000 [s] 	 Iter: 5 	 Error: 1.559360e-09 [cm]
# Time: 0.8000 [s] 	 Iter: 5 	 Error: 2.649446e-09 [cm]
# Time: 0.9000 [s] 	 Iter: 5 	 Error: 4.224711e-09 [cm]
# Time: 1.0000 [s] 	 Iter: 5 	 Error: 6.407829e-09 [cm]
#
#  Performing simulation with h = 0.05 and dt = 0.05.
#
# Time: 0.0500 [s] 	 Iter: 4 	 Error: 1.271738e-11 [cm]
# Time: 0.1000 [s] 	 Iter: 4 	 Error: 1.129439e-10 [cm]
# Time: 0.1500 [s] 	 Iter: 4 	 Error: 3.933582e-10 [cm]
# Time: 0.2000 [s] 	 Iter: 4 	 Error: 9.459673e-10 [cm]
# Time: 0.2500 [s] 	 Iter: 4 	 Error: 1.862127e-09 [cm]
# Time: 0.3000 [s] 	 Iter: 4 	 Error: 3.232545e-09 [cm]
# Time: 0.3500 [s] 	 Iter: 4 	 Error: 5.147273e-09 [cm]
# Time: 0.4000 [s] 	 Iter: 4 	 Error: 7.695707e-09 [cm]
# Time: 0.4500 [s] 	 Iter: 5 	 Error: 7.672285e-11 [cm]
# Time: 0.5000 [s] 	 Iter: 5 	 Error: 1.170541e-10 [cm]
# Time: 0.5500 [s] 	 Iter: 5 	 Error: 1.714571e-10 [cm]
# Time: 0.6000 [s] 	 Iter: 5 	 Error: 2.428460e-10 [cm]
# Time: 0.6500 [s] 	 Iter: 5 	 Error: 3.343992e-10 [cm]
# Time: 0.7000 [s] 	 Iter: 5 	 Error: 4.495546e-10 [cm]
# Time: 0.7500 [s] 	 Iter: 5 	 Error: 5.920084e-10 [cm]
# Time: 0.8000 [s] 	 Iter: 5 	 Error: 7.657115e-10 [cm]
# Time: 0.8500 [s] 	 Iter: 5 	 Error: 9.748655e-10 [cm]
# Time: 0.9000 [s] 	 Iter: 5 	 Error: 1.223923e-09 [cm]
# Time: 0.9500 [s] 	 Iter: 5 	 Error: 1.517580e-09 [cm]
# Time: 1.0000 [s] 	 Iter: 5 	 Error: 1.860778e-09 [cm]
#
#  Performing simulation with h = 0.025 and dt = 0.025.
#
# Time: 0.0250 [s] 	 Iter: 3 	 Error: 9.064673e-10 [cm]
# Time: 0.0500 [s] 	 Iter: 3 	 Error: 4.295866e-09 [cm]
# Time: 0.0750 [s] 	 Iter: 4 	 Error: 1.342171e-11 [cm]
# Time: 0.1000 [s] 	 Iter: 4 	 Error: 3.296030e-11 [cm]
# Time: 0.1250 [s] 	 Iter: 4 	 Error: 6.571321e-11 [cm]
# Time: 0.1500 [s] 	 Iter: 4 	 Error: 1.150855e-10 [cm]
# Time: 0.1750 [s] 	 Iter: 4 	 Error: 1.844795e-10 [cm]
# Time: 0.2000 [s] 	 Iter: 4 	 Error: 2.772942e-10 [cm]
# Time: 0.2250 [s] 	 Iter: 4 	 Error: 3.969267e-10 [cm]
# Time: 0.2500 [s] 	 Iter: 4 	 Error: 5.467700e-10 [cm]
# Time: 0.2750 [s] 	 Iter: 4 	 Error: 7.302143e-10 [cm]
# Time: 0.3000 [s] 	 Iter: 4 	 Error: 9.506467e-10 [cm]
# Time: 0.3250 [s] 	 Iter: 4 	 Error: 1.211451e-09 [cm]
# Time: 0.3500 [s] 	 Iter: 4 	 Error: 1.516007e-09 [cm]
# Time: 0.3750 [s] 	 Iter: 4 	 Error: 1.867693e-09 [cm]
# Time: 0.4000 [s] 	 Iter: 4 	 Error: 2.269881e-09 [cm]
# Time: 0.4250 [s] 	 Iter: 4 	 Error: 2.725942e-09 [cm]
# Time: 0.4500 [s] 	 Iter: 4 	 Error: 3.239242e-09 [cm]
# Time: 0.4750 [s] 	 Iter: 4 	 Error: 3.813142e-09 [cm]
# Time: 0.5000 [s] 	 Iter: 4 	 Error: 4.451003e-09 [cm]
# Time: 0.5250 [s] 	 Iter: 4 	 Error: 5.156179e-09 [cm]
# Time: 0.5500 [s] 	 Iter: 4 	 Error: 5.932021e-09 [cm]
# Time: 0.5750 [s] 	 Iter: 4 	 Error: 6.781875e-09 [cm]
# Time: 0.6000 [s] 	 Iter: 4 	 Error: 7.709085e-09 [cm]
# Time: 0.6250 [s] 	 Iter: 4 	 Error: 8.716990e-09 [cm]
# Time: 0.6500 [s] 	 Iter: 4 	 Error: 9.808924e-09 [cm]
# Time: 0.6750 [s] 	 Iter: 5 	 Error: 6.603607e-11 [cm]
# Time: 0.7000 [s] 	 Iter: 5 	 Error: 7.648371e-11 [cm]
# Time: 0.7250 [s] 	 Iter: 5 	 Error: 8.812684e-11 [cm]
# Time: 0.7500 [s] 	 Iter: 5 	 Error: 1.010538e-10 [cm]
# Time: 0.7750 [s] 	 Iter: 5 	 Error: 1.153559e-10 [cm]
# Time: 0.8000 [s] 	 Iter: 5 	 Error: 1.311284e-10 [cm]
# Time: 0.8250 [s] 	 Iter: 5 	 Error: 1.484688e-10 [cm]
# Time: 0.8500 [s] 	 Iter: 5 	 Error: 1.674783e-10 [cm]
# Time: 0.8750 [s] 	 Iter: 5 	 Error: 1.882612e-10 [cm]
# Time: 0.9000 [s] 	 Iter: 5 	 Error: 2.109251e-10 [cm]
# Time: 0.9250 [s] 	 Iter: 5 	 Error: 2.355807e-10 [cm]
# Time: 0.9500 [s] 	 Iter: 5 	 Error: 2.623419e-10 [cm]
# Time: 0.9750 [s] 	 Iter: 5 	 Error: 2.913261e-10 [cm]
# Time: 1.0000 [s] 	 Iter: 5 	 Error: 3.226535e-10 [cm]
#
#  Performing simulation with h = 0.0125 and dt = 0.0125.
#
# Time: 0.0125 [s] 	 Iter: 3 	 Error: 4.644796e-11 [cm]
# Time: 0.0250 [s] 	 Iter: 3 	 Error: 2.862213e-10 [cm]
# Time: 0.0375 [s] 	 Iter: 3 	 Error: 7.195953e-10 [cm]
# Time: 0.0500 [s] 	 Iter: 3 	 Error: 1.346780e-09 [cm]
# Time: 0.0625 [s] 	 Iter: 3 	 Error: 2.167965e-09 [cm]
# Time: 0.0750 [s] 	 Iter: 3 	 Error: 3.183339e-09 [cm]
# Time: 0.0875 [s] 	 Iter: 3 	 Error: 4.393087e-09 [cm]
# Time: 0.1000 [s] 	 Iter: 3 	 Error: 5.797398e-09 [cm]
# Time: 0.1125 [s] 	 Iter: 3 	 Error: 7.396458e-09 [cm]
# Time: 0.1250 [s] 	 Iter: 3 	 Error: 9.190453e-09 [cm]
# Time: 0.1375 [s] 	 Iter: 4 	 Error: 1.911049e-11 [cm]
# Time: 0.1500 [s] 	 Iter: 4 	 Error: 2.498202e-11 [cm]
# Time: 0.1625 [s] 	 Iter: 4 	 Error: 3.194822e-11 [cm]
# Time: 0.1750 [s] 	 Iter: 4 	 Error: 4.010281e-11 [cm]
# Time: 0.1875 [s] 	 Iter: 4 	 Error: 4.954059e-11 [cm]
# Time: 0.2000 [s] 	 Iter: 4 	 Error: 6.035528e-11 [cm]
# Time: 0.2125 [s] 	 Iter: 4 	 Error: 7.264123e-11 [cm]
# Time: 0.2250 [s] 	 Iter: 4 	 Error: 8.649281e-11 [cm]
# Time: 0.2375 [s] 	 Iter: 4 	 Error: 1.020046e-10 [cm]
# Time: 0.2500 [s] 	 Iter: 4 	 Error: 1.192713e-10 [cm]
# Time: 0.2625 [s] 	 Iter: 4 	 Error: 1.383871e-10 [cm]
# Time: 0.2750 [s] 	 Iter: 4 	 Error: 1.594473e-10 [cm]
# Time: 0.2875 [s] 	 Iter: 4 	 Error: 1.825471e-10 [cm]
# Time: 0.3000 [s] 	 Iter: 4 	 Error: 2.077805e-10 [cm]
# Time: 0.3125 [s] 	 Iter: 4 	 Error: 2.352432e-10 [cm]
# Time: 0.3250 [s] 	 Iter: 4 	 Error: 2.650302e-10 [cm]
# Time: 0.3375 [s] 	 Iter: 4 	 Error: 2.972369e-10 [cm]
# Time: 0.3500 [s] 	 Iter: 4 	 Error: 3.319587e-10 [cm]
# Time: 0.3625 [s] 	 Iter: 4 	 Error: 3.692908e-10 [cm]
# Time: 0.3750 [s] 	 Iter: 4 	 Error: 4.093290e-10 [cm]
# Time: 0.3875 [s] 	 Iter: 4 	 Error: 4.521687e-10 [cm]
# Time: 0.4000 [s] 	 Iter: 4 	 Error: 4.979059e-10 [cm]
# Time: 0.4125 [s] 	 Iter: 4 	 Error: 5.466361e-10 [cm]
# Time: 0.4250 [s] 	 Iter: 4 	 Error: 5.984553e-10 [cm]
# Time: 0.4375 [s] 	 Iter: 4 	 Error: 6.534597e-10 [cm]
# Time: 0.4500 [s] 	 Iter: 4 	 Error: 7.117453e-10 [cm]
# Time: 0.4625 [s] 	 Iter: 4 	 Error: 7.734082e-10 [cm]
# Time: 0.4750 [s] 	 Iter: 4 	 Error: 8.385446e-10 [cm]
# Time: 0.4875 [s] 	 Iter: 4 	 Error: 9.072512e-10 [cm]
# Time: 0.5000 [s] 	 Iter: 4 	 Error: 9.796239e-10 [cm]
# Time: 0.5125 [s] 	 Iter: 4 	 Error: 1.055760e-09 [cm]
# Time: 0.5250 [s] 	 Iter: 4 	 Error: 1.135755e-09 [cm]
# Time: 0.5375 [s] 	 Iter: 4 	 Error: 1.219707e-09 [cm]
# Time: 0.5500 [s] 	 Iter: 4 	 Error: 1.307711e-09 [cm]
# Time: 0.5625 [s] 	 Iter: 4 	 Error: 1.399865e-09 [cm]
# Time: 0.5750 [s] 	 Iter: 4 	 Error: 1.496266e-09 [cm]
# Time: 0.5875 [s] 	 Iter: 4 	 Error: 1.597011e-09 [cm]
# Time: 0.6000 [s] 	 Iter: 4 	 Error: 1.702197e-09 [cm]
# Time: 0.6125 [s] 	 Iter: 4 	 Error: 1.811921e-09 [cm]
# Time: 0.6250 [s] 	 Iter: 4 	 Error: 1.926281e-09 [cm]
# Time: 0.6375 [s] 	 Iter: 4 	 Error: 2.045373e-09 [cm]
# Time: 0.6500 [s] 	 Iter: 4 	 Error: 2.169295e-09 [cm]
# Time: 0.6625 [s] 	 Iter: 4 	 Error: 2.298145e-09 [cm]
# Time: 0.6750 [s] 	 Iter: 4 	 Error: 2.432021e-09 [cm]
# Time: 0.6875 [s] 	 Iter: 4 	 Error: 2.571019e-09 [cm]
# Time: 0.7000 [s] 	 Iter: 4 	 Error: 2.715238e-09 [cm]
# Time: 0.7125 [s] 	 Iter: 4 	 Error: 2.864776e-09 [cm]
# Time: 0.7250 [s] 	 Iter: 4 	 Error: 3.019730e-09 [cm]
# Time: 0.7375 [s] 	 Iter: 4 	 Error: 3.180198e-09 [cm]
# Time: 0.7500 [s] 	 Iter: 4 	 Error: 3.346279e-09 [cm]
# Time: 0.7625 [s] 	 Iter: 4 	 Error: 3.518070e-09 [cm]
# Time: 0.7750 [s] 	 Iter: 4 	 Error: 3.695670e-09 [cm]
# Time: 0.7875 [s] 	 Iter: 4 	 Error: 3.879178e-09 [cm]
# Time: 0.8000 [s] 	 Iter: 4 	 Error: 4.068690e-09 [cm]
# Time: 0.8125 [s] 	 Iter: 4 	 Error: 4.264307e-09 [cm]
# Time: 0.8250 [s] 	 Iter: 4 	 Error: 4.466125e-09 [cm]
# Time: 0.8375 [s] 	 Iter: 4 	 Error: 4.674245e-09 [cm]
# Time: 0.8500 [s] 	 Iter: 4 	 Error: 4.888764e-09 [cm]
# Time: 0.8625 [s] 	 Iter: 4 	 Error: 5.109781e-09 [cm]
# Time: 0.8750 [s] 	 Iter: 4 	 Error: 5.337396e-09 [cm]
# Time: 0.8875 [s] 	 Iter: 4 	 Error: 5.571706e-09 [cm]
# Time: 0.9000 [s] 	 Iter: 4 	 Error: 5.812810e-09 [cm]
# Time: 0.9125 [s] 	 Iter: 4 	 Error: 6.060809e-09 [cm]
# Time: 0.9250 [s] 	 Iter: 4 	 Error: 6.315800e-09 [cm]
# Time: 0.9375 [s] 	 Iter: 4 	 Error: 6.577884e-09 [cm]
# Time: 0.9500 [s] 	 Iter: 4 	 Error: 6.847158e-09 [cm]
# Time: 0.9625 [s] 	 Iter: 4 	 Error: 7.123722e-09 [cm]
# Time: 0.9750 [s] 	 Iter: 4 	 Error: 7.407676e-09 [cm]
# Time: 0.9875 [s] 	 Iter: 4 	 Error: 7.699119e-09 [cm]
# Time: 1.0000 [s] 	 Iter: 4 	 Error: 7.998150e-09 [cm]
#
#  Performing simulation with h = 0.00625 and dt = 0.00625.
#
# Time: 0.0063 [s] 	 Iter: 3 	 Error: 1.797007e-12 [cm]
# Time: 0.0125 [s] 	 Iter: 3 	 Error: 1.316347e-11 [cm]
# Time: 0.0188 [s] 	 Iter: 3 	 Error: 3.888201e-11 [cm]
# Time: 0.0250 [s] 	 Iter: 3 	 Error: 7.737877e-11 [cm]
# Time: 0.0312 [s] 	 Iter: 3 	 Error: 1.286669e-10 [cm]
# Time: 0.0375 [s] 	 Iter: 3 	 Error: 1.927600e-10 [cm]
# Time: 0.0438 [s] 	 Iter: 3 	 Error: 2.696710e-10 [cm]
# Time: 0.0500 [s] 	 Iter: 3 	 Error: 3.594123e-10 [cm]
# Time: 0.0563 [s] 	 Iter: 3 	 Error: 4.619976e-10 [cm]
# Time: 0.0625 [s] 	 Iter: 3 	 Error: 5.774394e-10 [cm]
# Time: 0.0688 [s] 	 Iter: 3 	 Error: 7.057510e-10 [cm]
# Time: 0.0750 [s] 	 Iter: 3 	 Error: 8.469445e-10 [cm]
# Time: 0.0813 [s] 	 Iter: 3 	 Error: 1.001034e-09 [cm]
# Time: 0.0875 [s] 	 Iter: 3 	 Error: 1.168031e-09 [cm]
# Time: 0.0938 [s] 	 Iter: 3 	 Error: 1.347949e-09 [cm]
# Time: 0.1000 [s] 	 Iter: 3 	 Error: 1.540801e-09 [cm]
# Time: 0.1063 [s] 	 Iter: 3 	 Error: 1.746599e-09 [cm]
# Time: 0.1125 [s] 	 Iter: 3 	 Error: 1.965357e-09 [cm]
# Time: 0.1188 [s] 	 Iter: 3 	 Error: 2.197087e-09 [cm]
# Time: 0.1250 [s] 	 Iter: 3 	 Error: 2.441803e-09 [cm]
# Time: 0.1313 [s] 	 Iter: 3 	 Error: 2.699516e-09 [cm]
# Time: 0.1375 [s] 	 Iter: 3 	 Error: 2.970239e-09 [cm]
# Time: 0.1438 [s] 	 Iter: 3 	 Error: 3.253985e-09 [cm]
# Time: 0.1500 [s] 	 Iter: 3 	 Error: 3.550768e-09 [cm]
# Time: 0.1562 [s] 	 Iter: 3 	 Error: 3.860599e-09 [cm]
# Time: 0.1625 [s] 	 Iter: 3 	 Error: 4.183491e-09 [cm]
# Time: 0.1688 [s] 	 Iter: 3 	 Error: 4.519457e-09 [cm]
# Time: 0.1750 [s] 	 Iter: 3 	 Error: 4.868510e-09 [cm]
# Time: 0.1813 [s] 	 Iter: 3 	 Error: 5.230662e-09 [cm]
# Time: 0.1875 [s] 	 Iter: 3 	 Error: 5.605926e-09 [cm]
# Time: 0.1938 [s] 	 Iter: 3 	 Error: 5.994313e-09 [cm]
# Time: 0.2000 [s] 	 Iter: 3 	 Error: 6.395838e-09 [cm]
# Time: 0.2063 [s] 	 Iter: 3 	 Error: 6.810511e-09 [cm]
# Time: 0.2125 [s] 	 Iter: 3 	 Error: 7.238347e-09 [cm]
# Time: 0.2188 [s] 	 Iter: 3 	 Error: 7.679357e-09 [cm]
# Time: 0.2250 [s] 	 Iter: 3 	 Error: 8.133554e-09 [cm]
# Time: 0.2313 [s] 	 Iter: 3 	 Error: 8.600950e-09 [cm]
# Time: 0.2375 [s] 	 Iter: 3 	 Error: 9.081558e-09 [cm]
# Time: 0.2438 [s] 	 Iter: 3 	 Error: 9.575389e-09 [cm]
# Time: 0.2500 [s] 	 Iter: 4 	 Error: 2.057465e-11 [cm]
# Time: 0.2563 [s] 	 Iter: 4 	 Error: 2.218559e-11 [cm]
# Time: 0.2625 [s] 	 Iter: 4 	 Error: 2.387912e-11 [cm]
# Time: 0.2687 [s] 	 Iter: 4 	 Error: 2.565703e-11 [cm]
# Time: 0.2750 [s] 	 Iter: 4 	 Error: 2.752132e-11 [cm]
# Time: 0.2812 [s] 	 Iter: 4 	 Error: 2.947398e-11 [cm]
# Time: 0.2875 [s] 	 Iter: 4 	 Error: 3.151723e-11 [cm]
# Time: 0.2938 [s] 	 Iter: 4 	 Error: 3.365330e-11 [cm]
# Time: 0.3000 [s] 	 Iter: 4 	 Error: 3.588418e-11 [cm]
# Time: 0.3063 [s] 	 Iter: 4 	 Error: 3.821166e-11 [cm]
# Time: 0.3125 [s] 	 Iter: 4 	 Error: 4.063838e-11 [cm]
# Time: 0.3188 [s] 	 Iter: 4 	 Error: 4.316592e-11 [cm]
# Time: 0.3250 [s] 	 Iter: 4 	 Error: 4.579670e-11 [cm]
# Time: 0.3313 [s] 	 Iter: 4 	 Error: 4.853251e-11 [cm]
# Time: 0.3375 [s] 	 Iter: 4 	 Error: 5.137601e-11 [cm]
# Time: 0.3438 [s] 	 Iter: 4 	 Error: 5.432854e-11 [cm]
# Time: 0.3500 [s] 	 Iter: 4 	 Error: 5.739298e-11 [cm]
# Time: 0.3563 [s] 	 Iter: 4 	 Error: 6.057088e-11 [cm]
# Time: 0.3625 [s] 	 Iter: 4 	 Error: 6.386425e-11 [cm]
# Time: 0.3688 [s] 	 Iter: 4 	 Error: 6.727596e-11 [cm]
# Time: 0.3750 [s] 	 Iter: 4 	 Error: 7.080736e-11 [cm]
# Time: 0.3813 [s] 	 Iter: 4 	 Error: 7.446088e-11 [cm]
# Time: 0.3875 [s] 	 Iter: 4 	 Error: 7.823853e-11 [cm]
# Time: 0.3938 [s] 	 Iter: 4 	 Error: 8.214274e-11 [cm]
# Time: 0.4000 [s] 	 Iter: 4 	 Error: 8.617507e-11 [cm]
# Time: 0.4062 [s] 	 Iter: 4 	 Error: 9.033796e-11 [cm]
# Time: 0.4125 [s] 	 Iter: 4 	 Error: 9.463363e-11 [cm]
# Time: 0.4188 [s] 	 Iter: 4 	 Error: 9.906409e-11 [cm]
# Time: 0.4250 [s] 	 Iter: 4 	 Error: 1.036315e-10 [cm]
# Time: 0.4313 [s] 	 Iter: 4 	 Error: 1.083378e-10 [cm]
# Time: 0.4375 [s] 	 Iter: 4 	 Error: 1.131852e-10 [cm]
# Time: 0.4438 [s] 	 Iter: 4 	 Error: 1.181764e-10 [cm]
# Time: 0.4500 [s] 	 Iter: 4 	 Error: 1.233127e-10 [cm]
# Time: 0.4563 [s] 	 Iter: 4 	 Error: 1.285965e-10 [cm]
# Time: 0.4625 [s] 	 Iter: 4 	 Error: 1.340301e-10 [cm]
# Time: 0.4688 [s] 	 Iter: 4 	 Error: 1.396157e-10 [cm]
# Time: 0.4750 [s] 	 Iter: 4 	 Error: 1.453551e-10 [cm]
# Time: 0.4813 [s] 	 Iter: 4 	 Error: 1.512508e-10 [cm]
# Time: 0.4875 [s] 	 Iter: 4 	 Error: 1.573046e-10 [cm]
# Time: 0.4938 [s] 	 Iter: 4 	 Error: 1.635190e-10 [cm]
# Time: 0.5000 [s] 	 Iter: 4 	 Error: 1.698961e-10 [cm]
# Time: 0.5062 [s] 	 Iter: 4 	 Error: 1.764375e-10 [cm]
# Time: 0.5125 [s] 	 Iter: 4 	 Error: 1.831462e-10 [cm]
# Time: 0.5188 [s] 	 Iter: 4 	 Error: 1.900238e-10 [cm]
# Time: 0.5250 [s] 	 Iter: 4 	 Error: 1.970726e-10 [cm]
# Time: 0.5312 [s] 	 Iter: 4 	 Error: 2.042948e-10 [cm]
# Time: 0.5375 [s] 	 Iter: 4 	 Error: 2.116924e-10 [cm]
# Time: 0.5438 [s] 	 Iter: 4 	 Error: 2.192677e-10 [cm]
# Time: 0.5500 [s] 	 Iter: 4 	 Error: 2.270231e-10 [cm]
# Time: 0.5563 [s] 	 Iter: 4 	 Error: 2.349603e-10 [cm]
# Time: 0.5625 [s] 	 Iter: 4 	 Error: 2.430818e-10 [cm]
# Time: 0.5687 [s] 	 Iter: 4 	 Error: 2.513894e-10 [cm]
# Time: 0.5750 [s] 	 Iter: 4 	 Error: 2.598857e-10 [cm]
# Time: 0.5813 [s] 	 Iter: 4 	 Error: 2.685727e-10 [cm]
# Time: 0.5875 [s] 	 Iter: 4 	 Error: 2.774525e-10 [cm]
# Time: 0.5938 [s] 	 Iter: 4 	 Error: 2.865275e-10 [cm]
# Time: 0.6000 [s] 	 Iter: 4 	 Error: 2.957998e-10 [cm]
# Time: 0.6063 [s] 	 Iter: 4 	 Error: 3.052714e-10 [cm]
# Time: 0.6125 [s] 	 Iter: 4 	 Error: 3.149447e-10 [cm]
# Time: 0.6188 [s] 	 Iter: 4 	 Error: 3.248217e-10 [cm]
# Time: 0.6250 [s] 	 Iter: 4 	 Error: 3.349045e-10 [cm]
# Time: 0.6313 [s] 	 Iter: 4 	 Error: 3.451956e-10 [cm]
# Time: 0.6375 [s] 	 Iter: 4 	 Error: 3.556970e-10 [cm]
# Time: 0.6438 [s] 	 Iter: 4 	 Error: 3.664111e-10 [cm]
# Time: 0.6500 [s] 	 Iter: 4 	 Error: 3.773399e-10 [cm]
# Time: 0.6562 [s] 	 Iter: 4 	 Error: 3.884857e-10 [cm]
# Time: 0.6625 [s] 	 Iter: 4 	 Error: 3.998506e-10 [cm]
# Time: 0.6688 [s] 	 Iter: 4 	 Error: 4.114367e-10 [cm]
# Time: 0.6750 [s] 	 Iter: 4 	 Error: 4.232463e-10 [cm]
# Time: 0.6813 [s] 	 Iter: 4 	 Error: 4.352818e-10 [cm]
# Time: 0.6875 [s] 	 Iter: 4 	 Error: 4.475451e-10 [cm]
# Time: 0.6938 [s] 	 Iter: 4 	 Error: 4.600387e-10 [cm]
# Time: 0.7000 [s] 	 Iter: 4 	 Error: 4.727647e-10 [cm]
# Time: 0.7063 [s] 	 Iter: 4 	 Error: 4.857250e-10 [cm]
# Time: 0.7125 [s] 	 Iter: 4 	 Error: 4.989225e-10 [cm]
# Time: 0.7188 [s] 	 Iter: 4 	 Error: 5.123588e-10 [cm]
# Time: 0.7250 [s] 	 Iter: 4 	 Error: 5.260363e-10 [cm]
# Time: 0.7313 [s] 	 Iter: 4 	 Error: 5.399572e-10 [cm]
# Time: 0.7375 [s] 	 Iter: 4 	 Error: 5.541241e-10 [cm]
# Time: 0.7438 [s] 	 Iter: 4 	 Error: 5.685383e-10 [cm]
# Time: 0.7500 [s] 	 Iter: 4 	 Error: 5.832030e-10 [cm]
# Time: 0.7563 [s] 	 Iter: 4 	 Error: 5.981200e-10 [cm]
# Time: 0.7625 [s] 	 Iter: 4 	 Error: 6.132914e-10 [cm]
# Time: 0.7688 [s] 	 Iter: 4 	 Error: 6.287197e-10 [cm]
# Time: 0.7750 [s] 	 Iter: 4 	 Error: 6.444070e-10 [cm]
# Time: 0.7812 [s] 	 Iter: 4 	 Error: 6.603555e-10 [cm]
# Time: 0.7875 [s] 	 Iter: 4 	 Error: 6.765677e-10 [cm]
# Time: 0.7938 [s] 	 Iter: 4 	 Error: 6.930454e-10 [cm]
# Time: 0.8000 [s] 	 Iter: 4 	 Error: 7.097911e-10 [cm]
# Time: 0.8063 [s] 	 Iter: 4 	 Error: 7.268071e-10 [cm]
# Time: 0.8125 [s] 	 Iter: 4 	 Error: 7.440955e-10 [cm]
# Time: 0.8188 [s] 	 Iter: 4 	 Error: 7.616585e-10 [cm]
# Time: 0.8250 [s] 	 Iter: 4 	 Error: 7.794985e-10 [cm]
# Time: 0.8313 [s] 	 Iter: 4 	 Error: 7.976177e-10 [cm]
# Time: 0.8375 [s] 	 Iter: 4 	 Error: 8.160181e-10 [cm]
# Time: 0.8438 [s] 	 Iter: 4 	 Error: 8.347028e-10 [cm]
# Time: 0.8500 [s] 	 Iter: 4 	 Error: 8.536729e-10 [cm]
# Time: 0.8563 [s] 	 Iter: 4 	 Error: 8.729313e-10 [cm]
# Time: 0.8625 [s] 	 Iter: 4 	 Error: 8.924801e-10 [cm]
# Time: 0.8688 [s] 	 Iter: 4 	 Error: 9.123216e-10 [cm]
# Time: 0.8750 [s] 	 Iter: 4 	 Error: 9.324583e-10 [cm]
# Time: 0.8813 [s] 	 Iter: 4 	 Error: 9.528920e-10 [cm]
# Time: 0.8875 [s] 	 Iter: 4 	 Error: 9.736252e-10 [cm]
# Time: 0.8938 [s] 	 Iter: 4 	 Error: 9.946604e-10 [cm]
# Time: 0.9000 [s] 	 Iter: 4 	 Error: 1.015999e-09 [cm]
# Time: 0.9062 [s] 	 Iter: 4 	 Error: 1.037644e-09 [cm]
# Time: 0.9125 [s] 	 Iter: 4 	 Error: 1.059598e-09 [cm]
# Time: 0.9188 [s] 	 Iter: 4 	 Error: 1.081863e-09 [cm]
# Time: 0.9250 [s] 	 Iter: 4 	 Error: 1.104441e-09 [cm]
# Time: 0.9313 [s] 	 Iter: 4 	 Error: 1.127334e-09 [cm]
# Time: 0.9375 [s] 	 Iter: 4 	 Error: 1.150545e-09 [cm]
# Time: 0.9438 [s] 	 Iter: 4 	 Error: 1.174076e-09 [cm]
# Time: 0.9500 [s] 	 Iter: 4 	 Error: 1.197929e-09 [cm]
# Time: 0.9563 [s] 	 Iter: 4 	 Error: 1.222106e-09 [cm]
# Time: 0.9625 [s] 	 Iter: 4 	 Error: 1.246611e-09 [cm]
# Time: 0.9688 [s] 	 Iter: 4 	 Error: 1.271444e-09 [cm]
# Time: 0.9750 [s] 	 Iter: 4 	 Error: 1.296609e-09 [cm]
# Time: 0.9813 [s] 	 Iter: 4 	 Error: 1.322107e-09 [cm]
# Time: 0.9875 [s] 	 Iter: 4 	 Error: 1.347941e-09 [cm]
# Time: 0.9938 [s] 	 Iter: 4 	 Error: 1.374114e-09 [cm]
# Time: 1.0000 [s] 	 Iter: 4 	 Error: 1.400627e-09 [cm]

# %% [markdown]
# ## Results

# %%
print("Spatial Step:    ",h)
print("Time Step   :    ",tau)
print("Global Error:    ",E)
print("Error Reduction: ",np.concatenate(([np.NaN],E_reduction)))
# Out:
# Spatial Step:     [0.1     0.05    0.025   0.0125  0.00625]
# Time Step   :     [0.1     0.05    0.025   0.0125  0.00625]
# Global Error:     [0.00488 0.0025  0.00126 0.00063 0.00031]
# Error Reduction:  [    nan 1.9538  1.98197 1.9998  2.01688]

# %% [markdown]
# ## References
# <a id='ref'></a>

# %% [markdown]
# [1]: *Aavatsmark, I. (2002). An introduction to multipoint flux approximations for quadrilateral grids. Computational Geosciences, 6(3-4), 405-432.*
#
# [2]: *Celia, M. A., Bouloutas, E. T., & Zarba, R. L. (1990). A general mass‐conservative numerical solution for the unsaturated flow equation. Water resources research, 26(7), 1483-1496.*
#
# [3]: *Radu, F. A., & Wang, W. (2014). Convergence analysis for a mixed finite element scheme for flow in strictly unsaturated porous media. Nonlinear Analysis: Real World Applications, 15, 266-275.*
