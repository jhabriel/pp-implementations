# %% [markdown]
# # Richards' Equation: Convergence Test #2

# %% [markdown]
# * Author: Jhabriel Varela
# * E-mail: jhabriel.varela@uib.no
# * Date: 05.04.2019
# * Institution: PMG - UiB - Norway

# %% [markdown]
# ## Description of the problem

# %% [markdown]
# In this second numerical convergence test of the Richards' Equation, instead of using relatively simple constitutive relationships as in [[1](#ref)], we use the well-known van Genuchten-Mualem retention curves [[2](#ref)] :
#
# $$
# \theta(\psi) = \frac{\theta_s - \theta_r}{\left[1 + \left(\alpha |\psi|\right)^n\right]^m} + \theta_s,
# $$
#
# $$
# k_r^w(\psi) = \frac{\Big\lbrace {1 - \left(\alpha |\psi|\right)^{n-1} \left[1 + \left(\alpha |\psi|\right)^n \right]^{-m} \Big\rbrace }^2}{\left[1 + \left(\alpha |\psi|\right)^n\right]^{m/2}},
# $$
#
# where $\alpha$, $n$ and $m$ are correlation parameters, $\theta_s$ is the water content at saturated conditions and $\theta_r$ is the residual water content. For this particular example, we use $\alpha = 0.04$, $n = 2$, $m = 0.5$, $\theta_s = 0.4$ and $\theta_r = 0.1$. Moreover, we neglect gravity contributions.
#
# The convergence analysis is carried out in the same way as we did in [[1](#ref)]. We use the same domain, boundary conditions, initial conditions, analytical solutions, spatial and time refinements and errors. Note that we are not showing the source term nor the Darcy's velocities expressions, since they are simply too long to show them.

# %% [markdown]
# ## Importing modules

# %%
import numpy as np
import scipy.sparse as sps
import porepy as pp
import matplotlib.pyplot as plt

from porepy.ad.forward_mode import Ad_array
np.set_printoptions(precision=5, suppress = True)

# %% [markdown]
# ## The convergence function

# %%
def convergence_richards(cell_num,time_levels):
    
    ## Computing relative permeabilities
    def arithmetic_mpfa_hyd(krw,g,bc,bc_val,psi_m0):
    
        """
        Computes the arithmetic average of the relative permability
        
        SYNOPSIS:
            arithmetic_mpfa_hyd(krw,g,bc_val,psi_m0)
        
        INPUT ARGUMENTS:
            krw         - Lambda function, relative permeability function krw = f(psi)
            g           - PorePy grid object
            bc_val      - NumPy array, containing values of boundary conditions
            psi_m0      - NumPy array, containing values of pressure head at the cell centers
        
        RETURNS:
            krw_ar      - Numpy array, contatining arithmetic averaged relative permeabilities 
                      at the face centers
        """
    
        neu_fcs = bc.is_neu.nonzero()    # neumann boundary faces
        dir_fcs = bc.is_dir.nonzero()    # dirichlet boundary faces
        int_fcs = g.get_internal_faces() # internal faces

        fcs_neigh = np.zeros((g.num_faces,2),dtype=int) #          
        fcs_neigh[:,0] = g.cell_face_as_dense()[0]      # faces neighbouring mapping
        fcs_neigh[:,1] = g.cell_face_as_dense()[1]      # 

        int_fcs_neigh = fcs_neigh[int_fcs]              # internal faces neighbouring mapping

        # Initializing 
        krw_ar = np.zeros(g.num_faces)

        # Neumann boundaries relative permeabilities
        krw_ar[neu_fcs] = 1.

        # Dirichlet boundaries relative permeabilities
        dir_cells_neigh = fcs_neigh[dir_fcs] # neighboring cells of dirichlet faces
        dir_cells = dir_cells_neigh[(dir_cells_neigh >= 0).nonzero()][0] # cells that share a dirichlet face
        krw_ar[dir_fcs] = 0.5 * (krw(bc_val[dir_fcs]) + 
                                 krw(psi_m0[dir_cells]))

        # Internal faces relative permeabilities
        krw_ar[int_fcs] = 0.5 * (krw(psi_m0[int_fcs_neigh[:,0]]) + 
                                 krw(psi_m0[int_fcs_neigh[:,1]]))

        return krw_ar

    ## The source term
    def source_term(g,t):
        
        x = g.cell_centers[0]
        y = g.cell_centers[1]
        
        f = (2*((np.sign(t*x*y*(x - 1)*(y - 1) + 1)*(t*x*y*(x - 1) + t*x*(x - 1)*(y - 1)))/(25*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/2)) - (np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2*np.sign(t*x*y*(x - 1)*(y - 1) + 1)*(t*x*y*(x - 1) + t*x*(x - 1)*(y - 1)))/(15625*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(3/2)))*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)/(25*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/2)) - 1)*(t*x*y*(x - 1) + t*x*(x - 1)*(y - 1)))/(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/4) + (2*((np.sign(t*x*y*(x - 1)*(y - 1) + 1)*(t*x*y*(y - 1) + t*y*(x - 1)*(y - 1)))/(25*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/2)) - (np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2*np.sign(t*x*y*(x - 1)*(y - 1) + 1)*(t*x*y*(y - 1) + t*y*(x - 1)*(y - 1)))/(15625*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(3/2)))*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)/(25*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/2)) - 1)*(t*x*y*(y - 1) + t*y*(x - 1)*(y - 1)))/(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/4) + (2*t*x*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)/(25*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/2)) - 1)**2*(x - 1))/(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/4) + (2*t*y*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)/(25*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/2)) - 1)**2*(y - 1))/(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/4) - (np.abs(t*x*y*(x - 1)*(y - 1) + 1)*np.sign(t*x*y*(x - 1)*(y - 1) + 1)*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)/(25*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/2)) - 1)**2*(t*x*y*(x - 1) + t*x*(x - 1)*(y - 1))**2)/(1250*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(5/4)) - (np.abs(t*x*y*(x - 1)*(y - 1) + 1)*np.sign(t*x*y*(x - 1)*(y - 1) + 1)*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)/(25*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(1/2)) - 1)**2*(t*x*y*(y - 1) + t*y*(x - 1)*(y - 1))**2)/(1250*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(5/4)) - (3*x*y*np.abs(t*x*y*(x - 1)*(y - 1) + 1)*np.sign(t*x*y*(x - 1)*(y - 1) + 1)*(x - 1)*(y - 1))/(6250*(np.abs(t*x*y*(x - 1)*(y - 1) + 1)**2/625 + 1)**(3/2))
        
        return f

    ## The analytical solution
    def analytical(g,t):
        
        x_cntr = g.cell_centers[0]
        y_cntr = g.cell_centers[1]
        x_face = g.face_centers[0]
        y_face = g.face_centers[1]
        
        psi = -t*x_cntr*(1-x_cntr)*y_cntr*(1-y_cntr)-1
        
        q_x = ((np.abs(t*x_face*y_face*(x_face - 1)*(y_face - 1) + 1)/(25*(np.abs(t*x_face*y_face*(x_face - 1)*(y_face - 1) + 1)**2/625 + 1)**(1/2)) - 1)**2*(t*x_face*y_face*(y_face - 1) + t*y_face*(x_face - 1)*(y_face - 1)))/(np.abs(t*x_face*y_face*(x_face - 1)*(y_face - 1) + 1)**2/625 + 1)**(1/4)
        q_y = ((np.abs(t*x_face*y_face*(x_face - 1)*(y_face - 1) + 1)/(25*(np.abs(t*x_face*y_face*(x_face - 1)*(y_face - 1) + 1)**2/625 + 1)**(1/2)) - 1)**2*(t*x_face*y_face*(x_face - 1) + t*x_face*(x_face - 1)*(y_face - 1)))/(np.abs(t*x_face*y_face*(x_face - 1)*(y_face - 1) + 1)**2/625 + 1)**(1/4)
        Q = q_x * g.face_normals[0] + q_y * g.face_normals[1]
        
        return psi,Q
    
    ## Setting up the grid
    Nx = Ny = cell_num
    Lx = 1; Ly = 1
    g = pp.CartGrid([Nx,Ny], [Lx,Ly])
    g.compute_geometry()
    V = g.cell_volumes
    
    # Physical parameters
    theta_s = 0.4
    theta_r = 0.1
    alpha = 0.04
    n = 2
    m = 1 - (1/n)
    
    ## Creating the permeability second order tensor          
    perm = pp.SecondOrderTensor(g.dim, np.ones(g.num_cells))
    
    ## Boundary and initial conditions
    b_faces = g.tags['domain_boundary_faces'].nonzero()[0]

    # Extracting indices of boundary faces w.r.t g
    x_min = b_faces[g.face_centers[0,b_faces] < 0.0001]
    x_max = b_faces[g.face_centers[0,b_faces] > 0.9999*Lx]
    y_min = b_faces[g.face_centers[1,b_faces] < 0.0001]
    y_max = b_faces[g.face_centers[1,b_faces] > 0.9999*Ly]
    
    # Extracting indices of boundary faces w.r.t b_faces
    west   = np.in1d(b_faces,x_min).nonzero()
    east   = np.in1d(b_faces,x_max).nonzero()
    south  = np.in1d(b_faces,y_min).nonzero()
    north  = np.in1d(b_faces,y_max).nonzero()
    
    # Setting the tags at each boundary side
    labels = np.array([None]*b_faces.size)
    labels[east]   = 'dir'
    labels[west]   = 'dir'
    labels[south]  = 'dir'
    labels[north]  = 'dir'
    
    # Constructing the bc object
    bc = pp.BoundaryCondition(g, b_faces, labels)
    
    # Constructing the boundary values array
    bc_val = -1 * np.ones(g.num_faces)
    
    ## Creating the data object
    specified_parameters = {"second_order_tensor": perm, 
                        "bc": bc, 
                        "bc_values": bc_val}

    data = pp.initialize_default_data(g,{},"flow", specified_parameters)
    
    ## Performing the discretization using MPFA  
    # Instatiating the pp.Mpfa class
    solver = pp.Mpfa("flow")

    # MPFA discretization
    mpfa_F, mpfa_boundF, _, _ = solver.mpfa(g, perm, bc)
    mpfa_div = pp.fvutils.scalar_divergence(g)
    
    ## Creating MPFA discrete operators
    F      = lambda x: mpfa_F * x
    boundF = lambda x: mpfa_boundF * x
    div    = lambda x: mpfa_div * x
    
    # Water content
    theta = lambda psi: (theta_s-theta_r)/(1 + (alpha*np.abs(psi))**n)**m + theta_s

    # Specific moisture capacity
    C = lambda psi: (-m*n*psi*(theta_s-theta_r)*(alpha*np.abs(psi))**n)/(np.abs(psi)**2 * (1 + (alpha*np.abs(psi))**n)**(m+1)); 

    # Relative permeability
    krw = lambda psi: (1 - (alpha*np.abs(psi))**(n-1) * (1 + (alpha*np.abs(psi))**n)**(-m))**2/(1 + (alpha*np.abs(psi))**n)**(m/2);
    
    # Arithmetic mean of relative permeability
    krw_ar = lambda psi_m: arithmetic_mpfa_hyd(krw,g,bc,bc_val,psi_m)

    # Multiphase Darcy Flux
    q = lambda psi,psi_m: (F(psi) + boundF(bc_val)) * krw_ar(psi_m)

    # Mass Conservation
    psi_eq = lambda psi,psi_n,psi_m,dt: div(q(psi,psi_m)) +  ((psi-psi_m)*C(psi_m) + 
                                                            theta(psi_m) - 
                                                            theta(psi_n)) * (V/dt) - \
                                                            source_term(g,times[tt]) * V
    
    ## Creating AD-object
    psi_ad = Ad_array(-1*np.ones(g.num_cells), sps.diags(np.ones(g.num_cells)))
    
    ## Time parameters
    t0 = 0                                # [s] Initial time
    tf = 1                                # [s] Final simulation time
    tLevels = time_levels                 # [-] Time levels
    times = np.linspace(t0,tf,tLevels+1)  # [s] Vector of time evaluations
    dt = np.diff(times)                   # [s] Vector of time steps

    ## Newton parameters
    newton_param = dict()
    newton_param['max_tol'] = 1E-8            # [cm] maximum absolute tolerance (pressure head)
    newton_param['max_iter'] = 10             # [iter] maximum number of iterations
    newton_param['abs_tol'] = 100             # [cm] absolute tolerance
    newton_param['iter'] = 1                  # [iter] iteration
    
    ## The time loop
    print("\n Performing simulation with h = {} and dt = {}. \n".format(1/Nx,dt[0]))
    
    tt = 0
    while times[tt] < tf:
           
        psi_n = psi_ad.val.copy()                                 # current time level
        newton_param.update({'abs_tol':100, 'iter':1})            # updating tolerance and iterations
        tt += 1
        
        # Newton loop
        while newton_param['abs_tol'] > newton_param['max_tol']   and \
              newton_param['iter']    < newton_param['max_iter']:      
              
            psi_m = psi_ad.val.copy()                                     # current iteration level
            eq = psi_eq(psi_ad,psi_n,psi_m,dt[tt-1])                      # calling discrete equation
            R = eq.val                                                    # determining residual
            J = eq.jac                                                    # determining Jacobian
            y = sps.linalg.spsolve(J,-R)                                  # Newton update
            psi_ad.val +=  y                                              # root for the k-th step
            newton_param['abs_tol'] = np.max(np.abs(psi_ad.val - psi_m))  # checking convergence        

            if newton_param['abs_tol'] <= newton_param['max_tol'] and newton_param['iter'] <= newton_param['max_iter']:
                print('Time: {0:4.4f} [s] \t Iter: {1:1d} \t Error: {2:4.3e} [cm]'.format(times[tt],newton_param['iter'],newton_param['abs_tol']))
            elif newton_param['iter'] > newton_param['max_iter']:
                 print('Error: Newton method did not converge!')
            else:
                 newton_param['iter'] += 1
                    
    ## Computing norm
    
    # Numerical results
    psi_num = psi_ad.val
    Q_num = q(psi_ad.val,psi_m)
    
    # Analytical results
    psi_ex,Q_ex = analytical(g,times[-1])
    
    # Global error
    E = (np.linalg.norm(psi_ex - psi_num)**2 + \
        dt[0] * np.linalg.norm(Q_ex - Q_num)**2)**(0.5)
    
    return E

# %% [markdown]
# ## Performing the analysis

# %%
# Number of cells and time levels
n_cells = np.array([10,20,40,80,160])
t_levels = np.array([10,20,40,80,160])
h = 1/n_cells
tau = 1/t_levels

# Intializing
E = np.zeros(len(n_cells))
E_reduction = np.zeros(len(n_cells)-1)

# Computing the errors
for i in range(len(E)):
    E[i] = convergence_richards(n_cells[i],t_levels[i])

# Computing the error reduction
for i in range(len(E_reduction)):
    E_reduction[i] = E[i]/E[i+1]
# Out:
#  Performing simulation with h = 0.1 and dt = 0.1.
#
# Time: 0.1000 [s] 	 Iter: 3 	 Error: 2.641e-10 [cm]
# Time: 0.2000 [s] 	 Iter: 3 	 Error: 1.059e-09 [cm]
# Time: 0.3000 [s] 	 Iter: 3 	 Error: 2.384e-09 [cm]
# Time: 0.4000 [s] 	 Iter: 3 	 Error: 4.240e-09 [cm]
# Time: 0.5000 [s] 	 Iter: 3 	 Error: 6.627e-09 [cm]
# Time: 0.6000 [s] 	 Iter: 3 	 Error: 9.546e-09 [cm]
# Time: 0.7000 [s] 	 Iter: 4 	 Error: 1.191e-11 [cm]
# Time: 0.8000 [s] 	 Iter: 4 	 Error: 1.779e-11 [cm]
# Time: 0.9000 [s] 	 Iter: 4 	 Error: 2.534e-11 [cm]
# Time: 1.0000 [s] 	 Iter: 4 	 Error: 3.478e-11 [cm]
#
#  Performing simulation with h = 0.05 and dt = 0.05.
#
# Time: 0.0500 [s] 	 Iter: 3 	 Error: 3.481e-11 [cm]
# Time: 0.1000 [s] 	 Iter: 3 	 Error: 1.397e-10 [cm]
# Time: 0.1500 [s] 	 Iter: 3 	 Error: 3.148e-10 [cm]
# Time: 0.2000 [s] 	 Iter: 3 	 Error: 5.600e-10 [cm]
# Time: 0.2500 [s] 	 Iter: 3 	 Error: 8.754e-10 [cm]
# Time: 0.3000 [s] 	 Iter: 3 	 Error: 1.261e-09 [cm]
# Time: 0.3500 [s] 	 Iter: 3 	 Error: 1.717e-09 [cm]
# Time: 0.4000 [s] 	 Iter: 3 	 Error: 2.243e-09 [cm]
# Time: 0.4500 [s] 	 Iter: 3 	 Error: 2.839e-09 [cm]
# Time: 0.5000 [s] 	 Iter: 3 	 Error: 3.506e-09 [cm]
# Time: 0.5500 [s] 	 Iter: 3 	 Error: 4.243e-09 [cm]
# Time: 0.6000 [s] 	 Iter: 3 	 Error: 5.050e-09 [cm]
# Time: 0.6500 [s] 	 Iter: 3 	 Error: 5.928e-09 [cm]
# Time: 0.7000 [s] 	 Iter: 3 	 Error: 6.876e-09 [cm]
# Time: 0.7500 [s] 	 Iter: 3 	 Error: 7.895e-09 [cm]
# Time: 0.8000 [s] 	 Iter: 3 	 Error: 8.983e-09 [cm]
# Time: 0.8500 [s] 	 Iter: 4 	 Error: 1.130e-11 [cm]
# Time: 0.9000 [s] 	 Iter: 4 	 Error: 1.342e-11 [cm]
# Time: 0.9500 [s] 	 Iter: 4 	 Error: 1.578e-11 [cm]
# Time: 1.0000 [s] 	 Iter: 4 	 Error: 1.841e-11 [cm]
#
#  Performing simulation with h = 0.025 and dt = 0.025.
#
# Time: 0.0250 [s] 	 Iter: 3 	 Error: 4.385e-12 [cm]
# Time: 0.0500 [s] 	 Iter: 3 	 Error: 1.766e-11 [cm]
# Time: 0.0750 [s] 	 Iter: 3 	 Error: 3.983e-11 [cm]
# Time: 0.1000 [s] 	 Iter: 3 	 Error: 7.090e-11 [cm]
# Time: 0.1250 [s] 	 Iter: 3 	 Error: 1.109e-10 [cm]
# Time: 0.1500 [s] 	 Iter: 3 	 Error: 1.597e-10 [cm]
# Time: 0.1750 [s] 	 Iter: 3 	 Error: 2.175e-10 [cm]
# Time: 0.2000 [s] 	 Iter: 3 	 Error: 2.841e-10 [cm]
# Time: 0.2250 [s] 	 Iter: 3 	 Error: 3.597e-10 [cm]
# Time: 0.2500 [s] 	 Iter: 3 	 Error: 4.442e-10 [cm]
# Time: 0.2750 [s] 	 Iter: 3 	 Error: 5.376e-10 [cm]
# Time: 0.3000 [s] 	 Iter: 3 	 Error: 6.398e-10 [cm]
# Time: 0.3250 [s] 	 Iter: 3 	 Error: 7.510e-10 [cm]
# Time: 0.3500 [s] 	 Iter: 3 	 Error: 8.711e-10 [cm]
# Time: 0.3750 [s] 	 Iter: 3 	 Error: 1.000e-09 [cm]
# Time: 0.4000 [s] 	 Iter: 3 	 Error: 1.138e-09 [cm]
# Time: 0.4250 [s] 	 Iter: 3 	 Error: 1.285e-09 [cm]
# Time: 0.4500 [s] 	 Iter: 3 	 Error: 1.441e-09 [cm]
# Time: 0.4750 [s] 	 Iter: 3 	 Error: 1.605e-09 [cm]
# Time: 0.5000 [s] 	 Iter: 3 	 Error: 1.779e-09 [cm]
# Time: 0.5250 [s] 	 Iter: 3 	 Error: 1.961e-09 [cm]
# Time: 0.5500 [s] 	 Iter: 3 	 Error: 2.153e-09 [cm]
# Time: 0.5750 [s] 	 Iter: 3 	 Error: 2.353e-09 [cm]
# Time: 0.6000 [s] 	 Iter: 3 	 Error: 2.562e-09 [cm]
# Time: 0.6250 [s] 	 Iter: 3 	 Error: 2.781e-09 [cm]
# Time: 0.6500 [s] 	 Iter: 3 	 Error: 3.008e-09 [cm]
# Time: 0.6750 [s] 	 Iter: 3 	 Error: 3.244e-09 [cm]
# Time: 0.7000 [s] 	 Iter: 3 	 Error: 3.489e-09 [cm]
# Time: 0.7250 [s] 	 Iter: 3 	 Error: 3.743e-09 [cm]
# Time: 0.7500 [s] 	 Iter: 3 	 Error: 4.006e-09 [cm]
# Time: 0.7750 [s] 	 Iter: 3 	 Error: 4.277e-09 [cm]
# Time: 0.8000 [s] 	 Iter: 3 	 Error: 4.558e-09 [cm]
# Time: 0.8250 [s] 	 Iter: 3 	 Error: 4.848e-09 [cm]
# Time: 0.8500 [s] 	 Iter: 3 	 Error: 5.146e-09 [cm]
# Time: 0.8750 [s] 	 Iter: 3 	 Error: 5.454e-09 [cm]
# Time: 0.9000 [s] 	 Iter: 3 	 Error: 5.770e-09 [cm]
# Time: 0.9250 [s] 	 Iter: 3 	 Error: 6.096e-09 [cm]
# Time: 0.9500 [s] 	 Iter: 3 	 Error: 6.430e-09 [cm]
# Time: 0.9750 [s] 	 Iter: 3 	 Error: 6.773e-09 [cm]
# Time: 1.0000 [s] 	 Iter: 3 	 Error: 7.126e-09 [cm]
#
#  Performing simulation with h = 0.0125 and dt = 0.0125.
#
# Time: 0.0125 [s] 	 Iter: 3 	 Error: 5.420e-13 [cm]
# Time: 0.0250 [s] 	 Iter: 3 	 Error: 2.198e-12 [cm]
# Time: 0.0375 [s] 	 Iter: 3 	 Error: 4.967e-12 [cm]
# Time: 0.0500 [s] 	 Iter: 3 	 Error: 8.852e-12 [cm]
# Time: 0.0625 [s] 	 Iter: 3 	 Error: 1.385e-11 [cm]
# Time: 0.0750 [s] 	 Iter: 3 	 Error: 1.996e-11 [cm]
# Time: 0.0875 [s] 	 Iter: 3 	 Error: 2.719e-11 [cm]
# Time: 0.1000 [s] 	 Iter: 3 	 Error: 3.553e-11 [cm]
# Time: 0.1125 [s] 	 Iter: 3 	 Error: 4.499e-11 [cm]
# Time: 0.1250 [s] 	 Iter: 3 	 Error: 5.556e-11 [cm]
# Time: 0.1375 [s] 	 Iter: 3 	 Error: 6.724e-11 [cm]
# Time: 0.1500 [s] 	 Iter: 3 	 Error: 8.004e-11 [cm]
# Time: 0.1625 [s] 	 Iter: 3 	 Error: 9.396e-11 [cm]
# Time: 0.1750 [s] 	 Iter: 3 	 Error: 1.090e-10 [cm]
# Time: 0.1875 [s] 	 Iter: 3 	 Error: 1.251e-10 [cm]
# Time: 0.2000 [s] 	 Iter: 3 	 Error: 1.424e-10 [cm]
# Time: 0.2125 [s] 	 Iter: 3 	 Error: 1.608e-10 [cm]
# Time: 0.2250 [s] 	 Iter: 3 	 Error: 1.803e-10 [cm]
# Time: 0.2375 [s] 	 Iter: 3 	 Error: 2.009e-10 [cm]
# Time: 0.2500 [s] 	 Iter: 3 	 Error: 2.226e-10 [cm]
# Time: 0.2625 [s] 	 Iter: 3 	 Error: 2.454e-10 [cm]
# Time: 0.2750 [s] 	 Iter: 3 	 Error: 2.694e-10 [cm]
# Time: 0.2875 [s] 	 Iter: 3 	 Error: 2.944e-10 [cm]
# Time: 0.3000 [s] 	 Iter: 3 	 Error: 3.206e-10 [cm]
# Time: 0.3125 [s] 	 Iter: 3 	 Error: 3.479e-10 [cm]
# Time: 0.3250 [s] 	 Iter: 3 	 Error: 3.763e-10 [cm]
# Time: 0.3375 [s] 	 Iter: 3 	 Error: 4.059e-10 [cm]
# Time: 0.3500 [s] 	 Iter: 3 	 Error: 4.365e-10 [cm]
# Time: 0.3625 [s] 	 Iter: 3 	 Error: 4.683e-10 [cm]
# Time: 0.3750 [s] 	 Iter: 3 	 Error: 5.012e-10 [cm]
# Time: 0.3875 [s] 	 Iter: 3 	 Error: 5.352e-10 [cm]
# Time: 0.4000 [s] 	 Iter: 3 	 Error: 5.703e-10 [cm]
# Time: 0.4125 [s] 	 Iter: 3 	 Error: 6.065e-10 [cm]
# Time: 0.4250 [s] 	 Iter: 3 	 Error: 6.439e-10 [cm]
# Time: 0.4375 [s] 	 Iter: 3 	 Error: 6.823e-10 [cm]
# Time: 0.4500 [s] 	 Iter: 3 	 Error: 7.219e-10 [cm]
# Time: 0.4625 [s] 	 Iter: 3 	 Error: 7.626e-10 [cm]
# Time: 0.4750 [s] 	 Iter: 3 	 Error: 8.044e-10 [cm]
# Time: 0.4875 [s] 	 Iter: 3 	 Error: 8.473e-10 [cm]
# Time: 0.5000 [s] 	 Iter: 3 	 Error: 8.914e-10 [cm]
# Time: 0.5125 [s] 	 Iter: 3 	 Error: 9.366e-10 [cm]
# Time: 0.5250 [s] 	 Iter: 3 	 Error: 9.828e-10 [cm]
# Time: 0.5375 [s] 	 Iter: 3 	 Error: 1.030e-09 [cm]
# Time: 0.5500 [s] 	 Iter: 3 	 Error: 1.079e-09 [cm]
# Time: 0.5625 [s] 	 Iter: 3 	 Error: 1.128e-09 [cm]
# Time: 0.5750 [s] 	 Iter: 3 	 Error: 1.179e-09 [cm]
# Time: 0.5875 [s] 	 Iter: 3 	 Error: 1.231e-09 [cm]
# Time: 0.6000 [s] 	 Iter: 3 	 Error: 1.284e-09 [cm]
# Time: 0.6125 [s] 	 Iter: 3 	 Error: 1.338e-09 [cm]
# Time: 0.6250 [s] 	 Iter: 3 	 Error: 1.393e-09 [cm]
# Time: 0.6375 [s] 	 Iter: 3 	 Error: 1.450e-09 [cm]
# Time: 0.6500 [s] 	 Iter: 3 	 Error: 1.507e-09 [cm]
# Time: 0.6625 [s] 	 Iter: 3 	 Error: 1.566e-09 [cm]
# Time: 0.6750 [s] 	 Iter: 3 	 Error: 1.625e-09 [cm]
# Time: 0.6875 [s] 	 Iter: 3 	 Error: 1.686e-09 [cm]
# Time: 0.7000 [s] 	 Iter: 3 	 Error: 1.748e-09 [cm]
# Time: 0.7125 [s] 	 Iter: 3 	 Error: 1.811e-09 [cm]
# Time: 0.7250 [s] 	 Iter: 3 	 Error: 1.875e-09 [cm]
# Time: 0.7375 [s] 	 Iter: 3 	 Error: 1.941e-09 [cm]
# Time: 0.7500 [s] 	 Iter: 3 	 Error: 2.007e-09 [cm]
# Time: 0.7625 [s] 	 Iter: 3 	 Error: 2.075e-09 [cm]
# Time: 0.7750 [s] 	 Iter: 3 	 Error: 2.143e-09 [cm]
# Time: 0.7875 [s] 	 Iter: 3 	 Error: 2.213e-09 [cm]
# Time: 0.8000 [s] 	 Iter: 3 	 Error: 2.284e-09 [cm]
# Time: 0.8125 [s] 	 Iter: 3 	 Error: 2.356e-09 [cm]
# Time: 0.8250 [s] 	 Iter: 3 	 Error: 2.429e-09 [cm]
# Time: 0.8375 [s] 	 Iter: 3 	 Error: 2.503e-09 [cm]
# Time: 0.8500 [s] 	 Iter: 3 	 Error: 2.579e-09 [cm]
# Time: 0.8625 [s] 	 Iter: 3 	 Error: 2.655e-09 [cm]
# Time: 0.8750 [s] 	 Iter: 3 	 Error: 2.733e-09 [cm]
# Time: 0.8875 [s] 	 Iter: 3 	 Error: 2.812e-09 [cm]
# Time: 0.9000 [s] 	 Iter: 3 	 Error: 2.891e-09 [cm]
# Time: 0.9125 [s] 	 Iter: 3 	 Error: 2.972e-09 [cm]
# Time: 0.9250 [s] 	 Iter: 3 	 Error: 3.054e-09 [cm]
# Time: 0.9375 [s] 	 Iter: 3 	 Error: 3.138e-09 [cm]
# Time: 0.9500 [s] 	 Iter: 3 	 Error: 3.222e-09 [cm]
# Time: 0.9625 [s] 	 Iter: 3 	 Error: 3.307e-09 [cm]
# Time: 0.9750 [s] 	 Iter: 3 	 Error: 3.394e-09 [cm]
# Time: 0.9875 [s] 	 Iter: 3 	 Error: 3.482e-09 [cm]
# Time: 1.0000 [s] 	 Iter: 3 	 Error: 3.570e-09 [cm]
#
#  Performing simulation with h = 0.00625 and dt = 0.00625.
#
# Time: 0.0063 [s] 	 Iter: 2 	 Error: 6.112e-09 [cm]
# Time: 0.0125 [s] 	 Iter: 3 	 Error: 2.702e-13 [cm]
# Time: 0.0188 [s] 	 Iter: 3 	 Error: 6.137e-13 [cm]
# Time: 0.0250 [s] 	 Iter: 3 	 Error: 1.096e-12 [cm]
# Time: 0.0312 [s] 	 Iter: 3 	 Error: 1.717e-12 [cm]
# Time: 0.0375 [s] 	 Iter: 3 	 Error: 2.477e-12 [cm]
# Time: 0.0438 [s] 	 Iter: 3 	 Error: 3.376e-12 [cm]
# Time: 0.0500 [s] 	 Iter: 3 	 Error: 4.414e-12 [cm]
# Time: 0.0563 [s] 	 Iter: 3 	 Error: 5.590e-12 [cm]
# Time: 0.0625 [s] 	 Iter: 3 	 Error: 6.906e-12 [cm]
# Time: 0.0688 [s] 	 Iter: 3 	 Error: 8.361e-12 [cm]
# Time: 0.0750 [s] 	 Iter: 3 	 Error: 9.954e-12 [cm]
# Time: 0.0813 [s] 	 Iter: 3 	 Error: 1.169e-11 [cm]
# Time: 0.0875 [s] 	 Iter: 3 	 Error: 1.356e-11 [cm]
# Time: 0.0938 [s] 	 Iter: 3 	 Error: 1.557e-11 [cm]
# Time: 0.1000 [s] 	 Iter: 3 	 Error: 1.772e-11 [cm]
# Time: 0.1063 [s] 	 Iter: 3 	 Error: 2.001e-11 [cm]
# Time: 0.1125 [s] 	 Iter: 3 	 Error: 2.243e-11 [cm]
# Time: 0.1188 [s] 	 Iter: 3 	 Error: 2.500e-11 [cm]
# Time: 0.1250 [s] 	 Iter: 3 	 Error: 2.770e-11 [cm]
# Time: 0.1313 [s] 	 Iter: 3 	 Error: 3.055e-11 [cm]
# Time: 0.1375 [s] 	 Iter: 3 	 Error: 3.353e-11 [cm]
# Time: 0.1438 [s] 	 Iter: 3 	 Error: 3.665e-11 [cm]
# Time: 0.1500 [s] 	 Iter: 3 	 Error: 3.991e-11 [cm]
# Time: 0.1562 [s] 	 Iter: 3 	 Error: 4.331e-11 [cm]
# Time: 0.1625 [s] 	 Iter: 3 	 Error: 4.685e-11 [cm]
# Time: 0.1688 [s] 	 Iter: 3 	 Error: 5.053e-11 [cm]
# Time: 0.1750 [s] 	 Iter: 3 	 Error: 5.434e-11 [cm]
# Time: 0.1813 [s] 	 Iter: 3 	 Error: 5.830e-11 [cm]
# Time: 0.1875 [s] 	 Iter: 3 	 Error: 6.240e-11 [cm]
# Time: 0.1938 [s] 	 Iter: 3 	 Error: 6.663e-11 [cm]
# Time: 0.2000 [s] 	 Iter: 3 	 Error: 7.100e-11 [cm]
# Time: 0.2063 [s] 	 Iter: 3 	 Error: 7.551e-11 [cm]
# Time: 0.2125 [s] 	 Iter: 3 	 Error: 8.016e-11 [cm]
# Time: 0.2188 [s] 	 Iter: 3 	 Error: 8.495e-11 [cm]
# Time: 0.2250 [s] 	 Iter: 3 	 Error: 8.988e-11 [cm]
# Time: 0.2313 [s] 	 Iter: 3 	 Error: 9.495e-11 [cm]
# Time: 0.2375 [s] 	 Iter: 3 	 Error: 1.002e-10 [cm]
# Time: 0.2438 [s] 	 Iter: 3 	 Error: 1.055e-10 [cm]
# Time: 0.2500 [s] 	 Iter: 3 	 Error: 1.110e-10 [cm]
# Time: 0.2563 [s] 	 Iter: 3 	 Error: 1.166e-10 [cm]
# Time: 0.2625 [s] 	 Iter: 3 	 Error: 1.224e-10 [cm]
# Time: 0.2687 [s] 	 Iter: 3 	 Error: 1.283e-10 [cm]
# Time: 0.2750 [s] 	 Iter: 3 	 Error: 1.343e-10 [cm]
# Time: 0.2812 [s] 	 Iter: 3 	 Error: 1.405e-10 [cm]
# Time: 0.2875 [s] 	 Iter: 3 	 Error: 1.468e-10 [cm]
# Time: 0.2938 [s] 	 Iter: 3 	 Error: 1.533e-10 [cm]
# Time: 0.3000 [s] 	 Iter: 3 	 Error: 1.599e-10 [cm]
# Time: 0.3063 [s] 	 Iter: 3 	 Error: 1.666e-10 [cm]
# Time: 0.3125 [s] 	 Iter: 3 	 Error: 1.735e-10 [cm]
# Time: 0.3188 [s] 	 Iter: 3 	 Error: 1.805e-10 [cm]
# Time: 0.3250 [s] 	 Iter: 3 	 Error: 1.877e-10 [cm]
# Time: 0.3313 [s] 	 Iter: 3 	 Error: 1.949e-10 [cm]
# Time: 0.3375 [s] 	 Iter: 3 	 Error: 2.024e-10 [cm]
# Time: 0.3438 [s] 	 Iter: 3 	 Error: 2.100e-10 [cm]
# Time: 0.3500 [s] 	 Iter: 3 	 Error: 2.177e-10 [cm]
# Time: 0.3563 [s] 	 Iter: 3 	 Error: 2.255e-10 [cm]
# Time: 0.3625 [s] 	 Iter: 3 	 Error: 2.335e-10 [cm]
# Time: 0.3688 [s] 	 Iter: 3 	 Error: 2.416e-10 [cm]
# Time: 0.3750 [s] 	 Iter: 3 	 Error: 2.499e-10 [cm]
# Time: 0.3813 [s] 	 Iter: 3 	 Error: 2.583e-10 [cm]
# Time: 0.3875 [s] 	 Iter: 3 	 Error: 2.668e-10 [cm]
# Time: 0.3938 [s] 	 Iter: 3 	 Error: 2.755e-10 [cm]
# Time: 0.4000 [s] 	 Iter: 3 	 Error: 2.844e-10 [cm]
# Time: 0.4062 [s] 	 Iter: 3 	 Error: 2.933e-10 [cm]
# Time: 0.4125 [s] 	 Iter: 3 	 Error: 3.024e-10 [cm]
# Time: 0.4188 [s] 	 Iter: 3 	 Error: 3.117e-10 [cm]
# Time: 0.4250 [s] 	 Iter: 3 	 Error: 3.210e-10 [cm]
# Time: 0.4313 [s] 	 Iter: 3 	 Error: 3.306e-10 [cm]
# Time: 0.4375 [s] 	 Iter: 3 	 Error: 3.402e-10 [cm]
# Time: 0.4438 [s] 	 Iter: 3 	 Error: 3.500e-10 [cm]
# Time: 0.4500 [s] 	 Iter: 3 	 Error: 3.600e-10 [cm]
# Time: 0.4563 [s] 	 Iter: 3 	 Error: 3.700e-10 [cm]
# Time: 0.4625 [s] 	 Iter: 3 	 Error: 3.802e-10 [cm]
# Time: 0.4688 [s] 	 Iter: 3 	 Error: 3.906e-10 [cm]
# Time: 0.4750 [s] 	 Iter: 3 	 Error: 4.011e-10 [cm]
# Time: 0.4813 [s] 	 Iter: 3 	 Error: 4.117e-10 [cm]
# Time: 0.4875 [s] 	 Iter: 3 	 Error: 4.225e-10 [cm]
# Time: 0.4938 [s] 	 Iter: 3 	 Error: 4.334e-10 [cm]
# Time: 0.5000 [s] 	 Iter: 3 	 Error: 4.445e-10 [cm]
# Time: 0.5062 [s] 	 Iter: 3 	 Error: 4.557e-10 [cm]
# Time: 0.5125 [s] 	 Iter: 3 	 Error: 4.670e-10 [cm]
# Time: 0.5188 [s] 	 Iter: 3 	 Error: 4.784e-10 [cm]
# Time: 0.5250 [s] 	 Iter: 3 	 Error: 4.901e-10 [cm]
# Time: 0.5312 [s] 	 Iter: 3 	 Error: 5.018e-10 [cm]
# Time: 0.5375 [s] 	 Iter: 3 	 Error: 5.137e-10 [cm]
# Time: 0.5438 [s] 	 Iter: 3 	 Error: 5.257e-10 [cm]
# Time: 0.5500 [s] 	 Iter: 3 	 Error: 5.379e-10 [cm]
# Time: 0.5563 [s] 	 Iter: 3 	 Error: 5.502e-10 [cm]
# Time: 0.5625 [s] 	 Iter: 3 	 Error: 5.626e-10 [cm]
# Time: 0.5687 [s] 	 Iter: 3 	 Error: 5.752e-10 [cm]
# Time: 0.5750 [s] 	 Iter: 3 	 Error: 5.879e-10 [cm]
# Time: 0.5813 [s] 	 Iter: 3 	 Error: 6.008e-10 [cm]
# Time: 0.5875 [s] 	 Iter: 3 	 Error: 6.138e-10 [cm]
# Time: 0.5938 [s] 	 Iter: 3 	 Error: 6.269e-10 [cm]
# Time: 0.6000 [s] 	 Iter: 3 	 Error: 6.402e-10 [cm]
# Time: 0.6063 [s] 	 Iter: 3 	 Error: 6.536e-10 [cm]
# Time: 0.6125 [s] 	 Iter: 3 	 Error: 6.672e-10 [cm]
# Time: 0.6188 [s] 	 Iter: 3 	 Error: 6.809e-10 [cm]
# Time: 0.6250 [s] 	 Iter: 3 	 Error: 6.947e-10 [cm]
# Time: 0.6313 [s] 	 Iter: 3 	 Error: 7.087e-10 [cm]
# Time: 0.6375 [s] 	 Iter: 3 	 Error: 7.228e-10 [cm]
# Time: 0.6438 [s] 	 Iter: 3 	 Error: 7.371e-10 [cm]
# Time: 0.6500 [s] 	 Iter: 3 	 Error: 7.515e-10 [cm]
# Time: 0.6562 [s] 	 Iter: 3 	 Error: 7.660e-10 [cm]
# Time: 0.6625 [s] 	 Iter: 3 	 Error: 7.807e-10 [cm]
# Time: 0.6688 [s] 	 Iter: 3 	 Error: 7.955e-10 [cm]
# Time: 0.6750 [s] 	 Iter: 3 	 Error: 8.104e-10 [cm]
# Time: 0.6813 [s] 	 Iter: 3 	 Error: 8.255e-10 [cm]
# Time: 0.6875 [s] 	 Iter: 3 	 Error: 8.408e-10 [cm]
# Time: 0.6938 [s] 	 Iter: 3 	 Error: 8.561e-10 [cm]
# Time: 0.7000 [s] 	 Iter: 3 	 Error: 8.716e-10 [cm]
# Time: 0.7063 [s] 	 Iter: 3 	 Error: 8.873e-10 [cm]
# Time: 0.7125 [s] 	 Iter: 3 	 Error: 9.031e-10 [cm]
# Time: 0.7188 [s] 	 Iter: 3 	 Error: 9.190e-10 [cm]
# Time: 0.7250 [s] 	 Iter: 3 	 Error: 9.351e-10 [cm]
# Time: 0.7313 [s] 	 Iter: 3 	 Error: 9.513e-10 [cm]
# Time: 0.7375 [s] 	 Iter: 3 	 Error: 9.676e-10 [cm]
# Time: 0.7438 [s] 	 Iter: 3 	 Error: 9.841e-10 [cm]
# Time: 0.7500 [s] 	 Iter: 3 	 Error: 1.001e-09 [cm]
# Time: 0.7563 [s] 	 Iter: 3 	 Error: 1.017e-09 [cm]
# Time: 0.7625 [s] 	 Iter: 3 	 Error: 1.034e-09 [cm]
# Time: 0.7688 [s] 	 Iter: 3 	 Error: 1.051e-09 [cm]
# Time: 0.7750 [s] 	 Iter: 3 	 Error: 1.069e-09 [cm]
# Time: 0.7812 [s] 	 Iter: 3 	 Error: 1.086e-09 [cm]
# Time: 0.7875 [s] 	 Iter: 3 	 Error: 1.103e-09 [cm]
# Time: 0.7938 [s] 	 Iter: 3 	 Error: 1.121e-09 [cm]
# Time: 0.8000 [s] 	 Iter: 3 	 Error: 1.139e-09 [cm]
# Time: 0.8063 [s] 	 Iter: 3 	 Error: 1.157e-09 [cm]
# Time: 0.8125 [s] 	 Iter: 3 	 Error: 1.175e-09 [cm]
# Time: 0.8188 [s] 	 Iter: 3 	 Error: 1.193e-09 [cm]
# Time: 0.8250 [s] 	 Iter: 3 	 Error: 1.211e-09 [cm]
# Time: 0.8313 [s] 	 Iter: 3 	 Error: 1.230e-09 [cm]
# Time: 0.8375 [s] 	 Iter: 3 	 Error: 1.248e-09 [cm]
# Time: 0.8438 [s] 	 Iter: 3 	 Error: 1.267e-09 [cm]
# Time: 0.8500 [s] 	 Iter: 3 	 Error: 1.286e-09 [cm]
# Time: 0.8563 [s] 	 Iter: 3 	 Error: 1.305e-09 [cm]
# Time: 0.8625 [s] 	 Iter: 3 	 Error: 1.324e-09 [cm]
# Time: 0.8688 [s] 	 Iter: 3 	 Error: 1.343e-09 [cm]
# Time: 0.8750 [s] 	 Iter: 3 	 Error: 1.363e-09 [cm]
# Time: 0.8813 [s] 	 Iter: 3 	 Error: 1.382e-09 [cm]
# Time: 0.8875 [s] 	 Iter: 3 	 Error: 1.402e-09 [cm]
# Time: 0.8938 [s] 	 Iter: 3 	 Error: 1.422e-09 [cm]
# Time: 0.9000 [s] 	 Iter: 3 	 Error: 1.442e-09 [cm]
# Time: 0.9062 [s] 	 Iter: 3 	 Error: 1.462e-09 [cm]
# Time: 0.9125 [s] 	 Iter: 3 	 Error: 1.482e-09 [cm]
# Time: 0.9188 [s] 	 Iter: 3 	 Error: 1.502e-09 [cm]
# Time: 0.9250 [s] 	 Iter: 3 	 Error: 1.523e-09 [cm]
# Time: 0.9313 [s] 	 Iter: 3 	 Error: 1.544e-09 [cm]
# Time: 0.9375 [s] 	 Iter: 3 	 Error: 1.564e-09 [cm]
# Time: 0.9438 [s] 	 Iter: 3 	 Error: 1.585e-09 [cm]
# Time: 0.9500 [s] 	 Iter: 3 	 Error: 1.606e-09 [cm]
# Time: 0.9563 [s] 	 Iter: 3 	 Error: 1.628e-09 [cm]
# Time: 0.9625 [s] 	 Iter: 3 	 Error: 1.649e-09 [cm]
# Time: 0.9688 [s] 	 Iter: 3 	 Error: 1.670e-09 [cm]
# Time: 0.9750 [s] 	 Iter: 3 	 Error: 1.692e-09 [cm]
# Time: 0.9813 [s] 	 Iter: 3 	 Error: 1.714e-09 [cm]
# Time: 0.9875 [s] 	 Iter: 3 	 Error: 1.736e-09 [cm]
# Time: 0.9938 [s] 	 Iter: 3 	 Error: 1.758e-09 [cm]
# Time: 1.0000 [s] 	 Iter: 3 	 Error: 1.780e-09 [cm]

# %% [markdown]
# ## Results

# %%
print("Spatial Step:    ",h)
print("Time Step   :    ",tau)
print("Global Error:    ",E)
print("Error Reduction: ",np.concatenate(([np.NaN],E_reduction)))
# Out:
# Spatial Step:     [0.1     0.05    0.025   0.0125  0.00625]
# Time Step   :     [0.1     0.05    0.025   0.0125  0.00625]
# Global Error:     [0.00486 0.00244 0.00122 0.00061 0.00031]
# Error Reduction:  [    nan 1.99395 1.99857 1.99984 2.00004]

# %% [markdown]
# ## References
# <a id='ref'></a>

# %% [markdown]
# [1]: <url>https://github.com/jhabriel/pp-implementations/blob/master/unsaturated_flow/convergence_richards/richards_convergence_1.ipynb
#
# [2]: *van Genuchten, M. T. (1980). A closed-form equation for predicting the hydraulic conductivity of unsaturated soils 1. Soil science society of America journal, 44(5), 892-898.*
